# %% [markdown]
# <a href="https://colab.research.google.com/github/humayun-mhk/Machine_Learning/blob/main/(2)_Linear_Regression%20For%20Multiple%20Features%20%26%20COST%20FUNCTION%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear_Regression For Multiple Features**

# %%
import numpy as np
import matplotlib.pyplot as plt
X_train = np.array([100,200,300])
Y_train = np.array([1000,3000,5000])
print(f"X_train = {X_train}")
print(f"Y_train = {Y_train}")
# Out:
# X_train = [100 200 300]
# Y_train = [1000 3000 5000]

# %%
# Plot the data points
plt.scatter(X_train, Y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
w = 20.000000000000004
b = -999.999999999999
def compute_model_output(x,w,b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w*x[i]+b
    return f_wb
model = compute_model_output(X_train,w,b)
print(model)
# Out:
# [1000. 3000. 5000.]

# %%
plt.plot(X_train, model, c='b',label='Our Prediction')
plt.scatter(X_train, Y_train, marker='x', c='r',label='Actual Values')
plt.title("Housing Prices")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# # **COST FUNCTION**

# %%
def compute_cost(x,y,w,b):
    m = x.shape[0]
    cost_sum = 0
    for i  in range(m):
        f_wb = w*x[i]+b
        cost = (f_wb - y[i])**2
        cost_sum = cost_sum + cost
    total_cost = (1/(2*m)) *cost_sum
    return total_cost
cost_fun = compute_cost(X_train,Y_train,w,b)
print(cost_fun)
# Out:
# 1.46695311757451e-24

# %% [markdown]
# # **VECTORIZATION**

# %%
import numpy as np
def dot_product(a,b):
    x =0
    for i in range(a.shape[0]):
        x  = x + a[i] * b[i]
    return x
print(dot_product(a,b))
print(f"Dot_product is : {np.dot(a,b)}")
import time
from random import randint
a = np.random.rand(10000000)
b = np.random.rand(10000000)
tic = time.time()
c = np.dot(a,b)
toc = time.time()
print(f"Dot product is : {c}")
print(F"Time taken by doct Product is : {1000*(tic-toc):.4f} ms")

tic = time.time()
c =  dot_product(a,b)
toc = time.time()
print(f"Dot product is : {c}")
print(F"Time taken by doct Product is : {1000*(tic-toc):.4f} ms")
# Out:
# 2500171.9909182717
# Dot_product is : 2500171.990918549
# Dot product is : 2499846.645638904
# Time taken by doct Product is : -12.3074 ms
# Dot product is : 2499846.6456387574
# Time taken by doct Product is : -3417.0358 ms
